# %% [markdown]
# <a href="https://colab.research.google.com/github/Schota/shares/blob/master/Insurance_claim_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Allstate insurance claim severity prediction (Regression)

# %% [markdown]
# This here is another competition on kaggle. The model we create is expected to predict the severity of a claim by predicting the loss corresponding to a set of features of the claim. The features are not named as such. We have two types of features - categorical and float numbers. There are a total of 132 features out of which some 116 are categorical.

# %% [markdown]
#  Since there is no specific detail in features, not even a name, we can not extract more faeture out of them. Anyways, we already got a lot of features.
# So all we do about features is categorical encoding and maybe scaling if we are applying such models.

# %% [markdown]
# ##Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##Importing datasets

# %% [markdown]
# You can download the dataset on kaggle site: https://www.kaggle.com/c/allstate-claims-severity/data

# %%
traindata = pd.read_csv('train.csv')
testdata = pd.read_csv('test.csv')

# %%
traindata
# Out:
#             id cat1 cat2 cat3  ...    cont12    cont13    cont14     loss
# 0            1    A    B    A  ...  0.594646  0.822493  0.714843  2213.18
# 1            2    A    B    A  ...  0.366307  0.611431  0.304496  1283.60
# 2            5    A    B    A  ...  0.373424  0.195709  0.774425  3005.09
# 3           10    B    B    A  ...  0.321570  0.605077  0.602642   939.85
# 4           11    A    B    A  ...  0.202213  0.246011  0.432606  2763.85
# ...        ...  ...  ...  ...  ...       ...       ...       ...      ...
# 188313  587620    A    B    A  ...  0.220003  0.333292  0.208216  1198.62
# 188314  587624    A    A    A  ...  0.301921  0.318646  0.305872  1108.34
# 188315  587630    A    B    A  ...  0.443374  0.339244  0.503888  5762.64
# 188316  587632    A    B    A  ...  0.852865  0.654753  0.721707  1562.87
# 188317  587633    B    A    A  ...  0.946432  0.810511  0.721460  4751.72
#
# [188318 rows x 132 columns]

# %% [markdown]
# ##Checking for any missing values

# %%
testdata.isnull().values.any()
# Out:
# False

# %%
traindata.isnull().values.any()
# Out:
# False

# %% [markdown]
# ##Encoding

# %% [markdown]
# One common problem that i saw with many datasets was that the number of unique categories in test set was something different than that in train set. This resulted in a problem because after applying get_dummies the number of columns differed in test and train sets. So here i wrote a one-liner to check for columns if thay had such a situation.

# %% [markdown]
# To check if there are different possible values in the columns of train and test data

# %%
traindata['cat90'].nunique() - testdata['cat90'].nunique()
# Out:
# 1

# %% [markdown]
# Using the above code we found a dojen of columns where the number of unique values differs. now we shall drop the corresponding columns.

# %%
features_drop = ['cat90', 'cat92', 'cat96', 'cat99', 'cat101', 'cat102', 'cat103', 'cat103', 'cat105', 'cat106', 'cat109', 'cat110', 'cat113', 'cat114', 'cat116']
traindata = traindata.drop(features_drop, axis=1)
testdata = testdata.drop(features_drop, axis=1)

# %%
traindata
# Out:
#             id cat1 cat2 cat3  ...    cont12    cont13    cont14     loss
# 0            1    A    B    A  ...  0.594646  0.822493  0.714843  2213.18
# 1            2    A    B    A  ...  0.366307  0.611431  0.304496  1283.60
# 2            5    A    B    A  ...  0.373424  0.195709  0.774425  3005.09
# 3           10    B    B    A  ...  0.321570  0.605077  0.602642   939.85
# 4           11    A    B    A  ...  0.202213  0.246011  0.432606  2763.85
# ...        ...  ...  ...  ...  ...       ...       ...       ...      ...
# 188313  587620    A    B    A  ...  0.220003  0.333292  0.208216  1198.62
# 188314  587624    A    A    A  ...  0.301921  0.318646  0.305872  1108.34
# 188315  587630    A    B    A  ...  0.443374  0.339244  0.503888  5762.64
# 188316  587632    A    B    A  ...  0.852865  0.654753  0.721707  1562.87
# 188317  587633    B    A    A  ...  0.946432  0.810511  0.721460  4751.72
#
# [188318 rows x 118 columns]

# %%
testdata
# Out:
#             id cat1 cat2 cat3  ...    cont11    cont12    cont13    cont14
# 0            4    A    B    A  ...  0.377724  0.369858  0.704052  0.392562
# 1            6    A    B    A  ...  0.689039  0.675759  0.453468  0.208045
# 2            9    A    B    A  ...  0.245410  0.241676  0.258586  0.297232
# 3           12    A    A    A  ...  0.348867  0.341872  0.592264  0.555955
# 4           15    B    A    A  ...  0.359572  0.352251  0.301535  0.825823
# ...        ...  ...  ...  ...  ...       ...       ...       ...       ...
# 125541  587617    A    A    A  ...  0.550529  0.538473  0.298734  0.345946
# 125542  587621    A    A    A  ...  0.324486  0.352251  0.490001  0.290576
# 125543  587627    B    B    A  ...  0.933174  0.926619  0.848129  0.808125
# 125544  587629    A    A    A  ...  0.307628  0.301921  0.608259  0.361542
# 125545  587634    A    B    A  ...  0.245410  0.241676  0.287682  0.220323
#
# [125546 rows x 117 columns]

# %% [markdown]
# Real encoding

# %%
traindata = pd.get_dummies(traindata, prefix_sep='_', drop_first=True)

# %%
traindata
# Out:
#             id     cont1     cont2  ...  cat115_U  cat115_W  cat115_X
# 0            1  0.726300  0.245921  ...         0         0         0
# 1            2  0.330514  0.737068  ...         0         0         0
# 2            5  0.261841  0.358319  ...         0         0         0
# 3           10  0.321594  0.555782  ...         0         0         0
# 4           11  0.273204  0.159990  ...         0         0         0
# ...        ...       ...       ...  ...       ...       ...       ...
# 188313  587620  0.347403  0.785784  ...         0         0         0
# 188314  587624  0.507661  0.555782  ...         0         0         0
# 188315  587630  0.484469  0.785784  ...         0         0         0
# 188316  587632  0.438385  0.422197  ...         0         0         0
# 188317  587633  0.907272  0.620805  ...         0         0         0
#
# [188318 rows x 316 columns]

# %%
testdata = pd.get_dummies(testdata, prefix_sep='_', drop_first=True)

# %%
testdata
# Out:
#             id     cont1     cont2  ...  cat115_U  cat115_W  cat115_X
# 0            4  0.321594  0.299102  ...         0         0         0
# 1            6  0.634734  0.620805  ...         0         0         0
# 2            9  0.290813  0.737068  ...         0         0         0
# 3           12  0.268622  0.681761  ...         0         0         0
# 4           15  0.553846  0.299102  ...         0         0         0
# ...        ...       ...       ...  ...       ...       ...       ...
# 125541  587617  0.458463  0.245921  ...         0         0         0
# 125542  587621  0.304143  0.488789  ...         0         0         0
# 125543  587627  0.899689  0.555782  ...         0         0         0
# 125544  587629  0.329232  0.358319  ...         0         0         0
# 125545  587634  0.310314  0.299102  ...         0         0         0
#
# [125546 rows x 315 columns]

# %% [markdown]
# ##Prepare for training

# %%
target = traindata.iloc[:, 15].values
target
# Out:
# array([2213.18, 1283.6 , 3005.09, ..., 5762.64, 1562.87, 4751.72])

# %%
traindata = traindata.drop('loss', axis=1)

# %%
traindata
# Out:
#             id     cont1     cont2  ...  cat115_U  cat115_W  cat115_X
# 0            1  0.726300  0.245921  ...         0         0         0
# 1            2  0.330514  0.737068  ...         0         0         0
# 2            5  0.261841  0.358319  ...         0         0         0
# 3           10  0.321594  0.555782  ...         0         0         0
# 4           11  0.273204  0.159990  ...         0         0         0
# ...        ...       ...       ...  ...       ...       ...       ...
# 188313  587620  0.347403  0.785784  ...         0         0         0
# 188314  587624  0.507661  0.555782  ...         0         0         0
# 188315  587630  0.484469  0.785784  ...         0         0         0
# 188316  587632  0.438385  0.422197  ...         0         0         0
# 188317  587633  0.907272  0.620805  ...         0         0         0
#
# [188318 rows x 315 columns]

# %%
X = traindata.iloc[:, 1:].values
y = target
X_test = testdata.iloc[:, 1:].values

# %% [markdown]
# ##Training

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()
regressor.fit(X, y)

# %% [markdown]
# ##Results

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred

# %% [markdown]
# ##Submission

# %%
y_pred = y_pred.tolist()

# %%
ID = testdata.iloc[:, 0]
ID = ID.tolist()

# %%
submit = {"id": ID, "loss": y_pred}
submit

# %%
len(X_test)

# %%
len(ID)

# %%
submission = pd.DataFrame(submit)
submission

# %%
submission.to_csv('predictions.csv', index = False)
